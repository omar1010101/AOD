# DatetimeIndex(['2023-06-24 15:05:48', '2023-06-24 15:22:51',
#                '2023-06-24 15:50:00', '2023-06-24 15:55:00',
#                '2023-06-24 16:00:00', '2023-06-24 16:05:00',
#                '2023-06-24 16:10:00', '2023-06-24 16:20:00',
#                '2023-06-24 16:30:00', '2023-07-07 20:37:52',
#                ...
#                '2024-03-01 01:40:00', '2024-03-01 02:40:00',
#                '2024-03-01 03:40:00', '2024-03-01 04:40:00',
#                '2024-03-01 05:40:00', '2024-03-01 06:40:00',
#                '2024-03-01 07:40:00', '2024-03-01 08:40:00',
#                '2024-03-01 09:40:00', '2024-03-01 10:40:00'],
#               dtype='datetime64[ns]', name='value_created_at', length=5704, freq=None)

# %%
diff = np.diff(nga.index)/1e9
diff = diff.astype(np.int32)
diff
# Out:
# array([1023, 1629,  300, ..., 3600, 3600, 3600])

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(diff)
plt.scatter(x=np.where(diff!=3600), y=diff[diff!=3600], color='red')

# %% [markdown]
# <b>Remarks:</b>
# - From the above plot we can see that not all points are 1-hour separated
# - And inconsistencies are occuring everywhere
# - Thus, we cannot have sufficient interval with 1-hour separated points
# - A possible solution is make an interpolation with available points, then sample every 1 hour from the interpolation

# %%
def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 300
X, y = df_to_X_y(nga, WINDOW_SIZE)
X.shape, y.shape
# Out:
# ((5404, 300, 1), (5404,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.55, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((1944, 300, 1), (1944,), (487, 300, 1), (487,), (2973, 300, 1), (2973,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((WINDOW_SIZE, 1)))
model1.add(LSTM(64))
model1.add(Dense(50, 'relu'))
model1.add(Dense(50, 'linear'))
model1.add(Dense(50, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 50)                  │           3,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,297 (98.82 KB)
#  Trainable params: 25,297 (98.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model_nga.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

# %%
if __name__=="__main__":

    experiment = get_mlflow_experiment(experiment_name="LSTM_epochs_10")
    print("Name: {}".format(experiment.name))

    with mlflow.start_run(run_name="logging_models_1", experiment_id=experiment.experiment_id) as run:

        model1 = Sequential()
        model1.add(InputLayer((WINDOW_SIZE, 1)))
        model1.add(LSTM(64))
        model1.add(Dense(50, 'relu'))
        model1.add(Dense(50, 'linear'))
        model1.add(Dense(50, 'relu'))
        model1.add(Dense(1, 'linear'))
        
        model1.summary()

        mlflow.autolog()
        
        model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
        model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp1])
        
        # log model 
        #mlflow.sklearn.log_model(sk_model=rfc, artifact_path="random_forest_classifier")
        

        # print info about the run
        print("run_id: {}".format(run.info.run_id))
        print("experiment_id: {}".format(run.info.experiment_id))
        print("status: {}".format(run.info.status))
        print("start_time: {}".format(run.info.start_time))
        print("end_time: {}".format(run.info.end_time))
        print("lifecycle_stage: {}".format(run.info.lifecycle_stage))

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, callbacks=[cp1])
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 26s 328ms/step - loss: 0.5224 - root_mean_squared_error: 0.6969 - val_loss: 0.4395 - val_root_mean_squared_error: 0.6630
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 286ms/step - loss: 0.0323 - root_mean_squared_error: 0.1726 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4531
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - loss: 0.0185 - root_mean_squared_error: 0.1292 - val_loss: 0.2373 - val_root_mean_squared_error: 0.4871
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 295ms/step - loss: 0.0510 - root_mean_squared_error: 0.2182 - val_loss: 0.1110 - val_root_mean_squared_error: 0.3332
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 303ms/step - loss: 0.0324 - root_mean_squared_error: 0.1779 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1865
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 323ms/step - loss: 0.0157 - root_mean_squared_error: 0.1156 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1879
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - loss: 0.0161 - root_mean_squared_error: 0.1241 - val_loss: 0.0430 - val_root_mean_squared_error: 0.2073
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 21s 336ms/step - loss: 0.0120 - root_mean_squared_error: 0.1012 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1956
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 330ms/step - loss: 0.0244 - root_mean_squared_error: 0.1494 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2172
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - loss: 0.0230 - root_mean_squared_error: 0.1484 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - loss: 0.0269 - root_mean_squared_error: 0.1576 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1921
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 317ms/step - loss: 0.0141 - root_mean_squared_error: 0.1103 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2619
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 16s 263ms/step - loss: 0.0121 - root_mean_squared_error: 0.1047 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - loss: 0.0078 - root_mean_squared_error: 0.0825 - val_loss: 0.0546 - val_root_mean_squared_error: 0.2336
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 293ms/step - loss: 0.0103 - root_mean_squared_error: 0.0975 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 16s 261ms/step - loss: 0.0321 - root_mean_squared_error: 0.1716 - val_loss: 0.0475 - val_root_mean_squared_error: 0.2179
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 288ms/step - loss: 0.0139 - root_mean_squared_error: 0.1135 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1968
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 296ms/step - loss: 0.0119 - root_mean_squared_error: 0.1072 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2151
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - loss: 0.0168 - root_mean_squared_error: 0.1252 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2051
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - loss: 0.0328 - root_mean_squared_error: 0.1705 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2193
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 298ms/step - loss: 0.0121 - root_mean_squared_error: 0.1065 - val_loss: 0.0626 - val_root_mean_squared_error: 0.2501
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 286ms/step - loss: 0.0193 - root_mean_squared_error: 0.1320 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 306ms/step - loss: 0.0114 - root_mean_squared_error: 0.1026 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1985
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 332ms/step - loss: 0.0220 - root_mean_squared_error: 0.1451 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2040

# %%
# from tensorflow.keras.models import load_model
# model1 = load_model('model_nga.keras')

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 12s 126ms/step
#       Test Predictions  Actuals
# 0             3.511593  3.90592
# 1             3.785411  3.06696
# 2             3.267376  3.46852
# 3             3.355209  3.75385
# 4             3.607483  3.88759
# ...                ...      ...
# 2968          0.573484  0.54927
# 2969          0.561495  0.52915
# 2970          0.546966  0.55540
# 2971          0.548199  0.50074
# 2972          0.529157  0.50810
#
# [2973 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2 = r2_score(y_test, model1.predict(X_test))
print(f"Score R²: {r2:.4f}")

mae = mean_absolute_error(y_test, model1.predict(X_test))
print(f"Mean absolute error: {mae:.4f}")

mse = mean_squared_error(y_test, model1.predict(X_test))
print(f"Mean squared error: {mse:.4f}")

rmse = np.sqrt(mse)
print(f"Mean squared error: {rmse:.4f}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step
# Score R²: 0.9703
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step
# Mean absolute error: 0.1131
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step
# Mean squared error: 0.0815
# Mean squared error: 0.2855

# %%
# import mlflow 
# def create_mlflow_experiments(experiment_name : str , artifact_location : str , tags ) -> str : 
#     try :
#         experiment_id = mlflow.create_experiment(
#         name = experiment_name,
#         artifact_location = artifact_location,
#         tags = tags,
#         )
#     except :
#         print(f"Experiment {experiment_name} already exits ........")
#         experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id
#     return experiment_id

# def get_mlflow_experiment(experiment_id : str = None , experiment_name:str = None) -> mlflow.entities.Experiment:
#     if experiment_id is not None :
#         experiment = mlflow.get_experiment(experiment_id)
#     elif experiment_name is not None :
#         experiment = mlflow.get_experiment_by_name(experiment_name)
#     else :
#         raise ValueError("Either experiment_id or experiment_name must be provided .")
#     return experiment

# if __name__ == "__main__" :
#     experiment_id = create_mlflow_experiments("LSTM_epochs_10","LSTM_epochs_10_artifacts",{"env" : "dev" , "version" : "1.0.0"})
#     print(f"Expirement ID : {experiment_id} ")

# %%
if __name__ == "__main__":

    experiment = get_mlflow_experiment(experiment_name="LSTM_v1")
    print("Name: {}".format(experiment.name))

    with mlflow.start_run(run_name=f"logging_LSTMv1_windows_size_{WINDOW_SIZE}", experiment_id = experiment.experiment_id) as run:

        # Your machine learning code goes here

        parameters = {
            "learning_rate": 0.001,
            "epochs": 100,
            "loss_function": "mse",
            "optimizer": "adam"
        }
        metrics = {
            "mse": mse,
            "mae": mae,
            "rmse": rmse,
            "r2": r2
        }

        mlflow.log_metrics(metrics)

        mlflow.log_params(parameters)

        # print run info
        print("run_id: {}".format(run.info.run_id))
        print("experiment_id: {}".format(run.info.experiment_id))
        print("status: {}".format(run.info.status))
        print("start_time: {}".format(run.info.start_time))
        print("end_time: {}".format(run.info.end_time))
        print("lifecycle_stage: {}".format(run.info.lifecycle_stage))
# Out:
# Name: LSTM_v1
# run_id: 4a1119b319b247c2944b444fb591a714
# experiment_id: 224601663755861703
# status: RUNNING
# start_time: 1723805104352
# end_time: None
# lifecycle_stage: active

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train})
train_results
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step
#       Train Predictions  Actuals
# 0              0.671051  0.67007
# 1              0.666087  0.70640
# 2              0.677514  0.67849
# 3              0.673193  0.67949
# 4              0.671272  0.74259
# ...                 ...      ...
# 1939           5.184277  5.37631
# 1940           5.313804  5.08788
# 1941           5.134547  5.31915
# 1942           5.246274  5.34283
# 1943           5.306734  5.74513
#
# [1944 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(train_results['Train Predictions'])
plt.plot(train_results['Actuals'])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#      Val Predictions  Actuals
# 0           5.637705  5.84498
# 1           5.823798  6.04112
# 2           6.019631  5.93638
# 3           5.989319  5.92907
# 4           5.956318  6.15638
# ..               ...      ...
# 482         3.506913  3.78645
# 483         3.734930  3.51800
# 484         3.615205  3.34877
# 485         3.423405  3.67250
# 486         3.576898  3.50187
#
# [487 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(val_results['Val Predictions'])
plt.plot(val_results['Actuals'])

fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(test_results['Test Predictions'])
plt.plot(test_results['Actuals'], linewidth=2, alpha=0.3, color='red')
